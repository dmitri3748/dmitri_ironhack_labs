# %%
# goal: predict total claim amount

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read data
df = pd.read_csv("Data_Marketing_Customer_Analysis_Round3.csv")

# %%
df.head()
# Out:
#         region  customer_lifetime_value response  coverage education  \
# 0      central                     4809       no     basic   college
# 1  west region                     2228       no     basic   college
# 2         east                    14947       no     basic  bachelor
# 3   north west                    22332      yes  extended   college
# 4   north west                     9025       no   premium  bachelor
#
#   effective_to_date month employment_status gender  income  ...  \
# 0           2/18/11   feb          employed      m   48029  ...
# 1           1/18/11   jan        unemployed      f   92260  ...
# 2           2/10/11   feb          employed      m   22139  ...
# 3           1/11/11   jan          employed      m   49078  ...
# 4           1/17/11   jan     medical leave      f   23675  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                         0                   9
# ...

# %%
df.tail()
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# 10684           1/19/11   jan        unemployed      f   61541  ...
# 10685            1/6/11   jan          employed      f   61146  ...
# 10686            2/6/11   feb          employed      f   39837  ...
# 10687           2/13/11   feb          employed      f   64195  ...
# 10688            1/8/11   jan        unemployed      m   68942  ...
#
#       months_since_policy_inception number_of_open_complaints  \
# ...

# %%
df.columns
# Out:
# Index(['region', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'month', 'employment_status',
#        'gender', 'income', 'location_code', 'marital_status',
#        'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %% [markdown]
# # Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
# numerical
# numerical = df.apply(lambda x: np.number(df.columns[x]))
# numerical1 = df.apply(lambda x: pd.to_numeric(x, errors='coerce'))
# df[['A', 'B']] = df[['A', 'B']].apply(pd.to_numeric)
# can I do it with an if statement? 
# for that I need to check the type of each column

# %%
numerical = df.select_dtypes(include = np.number)

# %%
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
categorical = df.select_dtypes(include = np.object)
# Out:
# /var/folders/wq/2vxkh_6d4g7dpxkr5q82nxzh0000gn/T/ipykernel_52345/3603834897.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = df.select_dtypes(include = np.object)

# %%
categorical
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# # Distribution plots for numericals

# %% [markdown]
# ## Plots with seaborn

# %%
numerical.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# ### Income

# %%
#how can I put them next to each other?
fig = plt.figure(figsize = (9,8))
# how do I bring the plot inside the figure

# %%
sns.distplot(numerical.income)
# Out:
# /Users/dmitrir./opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %% [markdown]
# ## Histogram with Matlpotlib

# %% [markdown]
# ### <font color=red> Is this NumPy above? ChatGPT!

# %%
numerical.hist(figsize=(10,15))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Correlation

# %%
numerical_no_tca = numerical.drop(columns=['total_claim_amount'])

# %%
numerical_no_tca.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.003732
# income                                        0.003732  1.000000
# monthly_premium_auto                          0.404235 -0.002431
# months_since_last_claim                       0.011912 -0.026564
# months_since_policy_inception                 0.017055  0.003846
# number_of_open_complaints                    -0.032371  0.018903
# number_of_policies                            0.016789 -0.004461
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.404235                 0.011912
# income                                    -0.002431                -0.026564
# monthly_premium_auto                       1.000000                 0.010036
# months_since_last_claim                    0.010036                 1.000000
# ...

# %%
sns.heatmap(numerical_no_tca.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# def binary_data(data):
#    return [1 if x in data else 0 for x in range(data[-1] + 1)]

# binary_data(df.response)

# %%
df.response
# Out:
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no
#         ...
# 10684     no
# 10685     no
# 10686     no
# 10687     no
# 10688     no
# Name: response, Length: 10689, dtype: object

# %%
df.response = df.response.apply(lambda x : 0 if x == 'no' else 1 if x == 'yes' else None)

# %%
df.response
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 10684    0
# 10685    0
# 10686    0
# 10687    0
# 10688    0
# Name: response, Length: 10689, dtype: int64

# %%
df.response.value_counts()
# Out:
# 0    9316
# 1    1373
# Name: response, dtype: int64

# %%
responses = df.response.value_counts()

# %%
responses.plot(kind='bar')
plt.show()

# %%
# Show a plot of the response by the sales channel.
responses_by_channel = df.groupby(['response', 'sales_channel'])['response'].count().rename('count').reset_index()

# %%
responses_by_channel
# we have agent, branch, call center, web
# there should be to in one
# Out:
#    response sales_channel  count
# 0         0         agent   3340
# 1         0        branch   2665
# 2         0   call center   1890
# 3         0           web   1421
# 4         1         agent    679
# 5         1        branch    310
# 6         1   call center    209
# 7         1           web    175

# %%
fig, axes = plt.subplots(figsize = (16,6))

sns.barplot(x='sales_channel', y='count', hue = 'response', data = responses_by_channel)

axes.set_title('Responses')
# Out:
# Text(0.5, 1.0, 'Responses')

# %%
# group by the ones who answered with tca
responses_by_tca = df.groupby(['response', 'total_claim_amount'])['response'].count().rename('count').reset_index()

# %%
responses_by_tca
# there seems to be a big difference between the ones who answered and the ones who have not answered
# Out:
#       response  total_claim_amount  count
# 0            0                   0      9
# 1            0                   1      9
# 2            0                   2     12
# 3            0                   3      9
# 4            0                   4     12
# ...        ...                 ...    ...
# 1358         1                1324      7
# 1359         1                1358      6
# 1360         1                1416      1
# 1361         1                1443      1
# 1362         1                1814      1
#
# [1363 rows x 3 columns]

# %%
df.total_claim_amount.value_counts()
# it is spread strongly as it seems
# Out:
# 316     147
# 292     143
# 350     137
# 312     128
# 331     123
#        ...
# 816       1
# 1980      1
# 1543      1
# 1562      1
# 1621      1
# Name: total_claim_amount, Length: 1172, dtype: int64

# %%
df.total_claim_amount.describe()
# stdev is huge in comparison to the mean
# there seem to be some huge outliers - I'd kick them out
# Out:
# count    10689.000000
# mean       434.227243
# std        292.550878
# min          0.000000
# 25%        269.000000
# 50%        383.000000
# 75%        547.000000
# max       2893.000000
# Name: total_claim_amount, dtype: float64

# %%
# would it be interesting to have two boxplots to see how they compare?

# %%
fig1, axes1 = plt.subplots(figsize = (16,6))

sns.barplot(x='total_claim_amount', y ='count', hue = 'response', data = responses_by_tca)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='count'>

# %%
yes_mean = responses_by_tca[responses_by_tca['response']=='yes']['total_claim_amount'].mean()
no_mean = responses_by_tca[responses_by_tca['response']=='no']['total_claim_amount'].mean()


sns.boxplot(data=responses_by_tca, x='response', y='total_claim_amount')
plt.plot([0, 1], [yes_mean, no_mean], marker='o', linestyle='--', color='red')


plt.title('Distribution of Claim Amount by Response')
plt.xlabel('Response')
plt.ylabel('Claim Amount')

plt.show()

# %%
responses_by_income = df.groupby(['response', 'income'])['response'].count().rename('count').reset_index()

# %%
yes_mean = responses_by_income[responses_by_income['response']=='yes']['income'].mean()
# need to change the groupby
no_mean = responses_by_income[responses_by_income['response']=='no']['income'].mean()


sns.boxplot(data=responses_by_income, x='response', y='income')
plt.plot([0, 1], [yes_mean, no_mean], marker='o', linestyle='--', color='red')


plt.title('Distribution of Income by Response')
plt.xlabel('Response')
plt.ylabel('Income')

plt.show()
