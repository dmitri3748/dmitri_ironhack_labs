# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## Scrapping

# %%
url = "https://www.billboard.com/charts/hot-100/#"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# find all containers with the information needed
containers = soup.find_all('div', class_='o-chart-results-list-row-container')

# get the information from each container
artists = []
songs = []
for container in containers:
    artists.append(container.find('h3').find_next('span').text.strip())
    songs.append(container.find('h3').text.strip())

# make a dataframe 
df = pd.DataFrame({'artist': artists, 'song': songs})

# %% [markdown]
# ## Python programme

# %%
# make a new column with artist and song
df['artist_song'] = df['artist'].str.cat(df['song'], sep=': ')
df['artist_song'] = df['artist_song'].apply(lambda x:x.lower())
df
# Out:
#                                               artist               song  \
# 0                                      Morgan Wallen         Last Night
# 1                                              Drake    Search & Rescue
# 2                                        Miley Cyrus            Flowers
# 3                                                SZA          Kill Bill
# 4               Metro Boomin, The Weeknd & 21 Savage           Creepin'
# ..                                               ...                ...
# 95                                      Old Dominion        Memory Lane
# 96                                      Carly Pearce  What He Didn't Do
# 97                       Carin Leon X Grupo Frontera        Que Vuelvas
# 98  YoungBoy Never Broke Again Featuring Nicki Minaj                WTF
# 99                                     Morgan Wallen         '98 Braves
#
#                                           artist_song
# 0                           morgan wallen: last night
# 1                              drake: search & rescue
# 2                                miley cyrus: flowers
# 3                                      sza: kill bill
# 4      metro boomin, the weeknd & 21 savage: creepin'
# ..                                                ...
# 95                          old dominion: memory lane
# 96                    carly pearce: what he didn't do
# 97           carin leon x grupo frontera: que vuelvas
# 98  youngboy never broke again featuring nicki min...
# 99                          morgan wallen: '98 braves
#
# [100 rows x 3 columns]

# %%
# get user input
user_input = input("What song shall be checked if it hot right now?").lower()

# check if song is in the list
if df['artist_song'].str.contains(user_input).any():
    random_number = np.random.randint(len(df))
    pick_random = df.artist_song[random_number].title()
    
    print(f'Your song is hot, here is another one! {pick_random}')
else:
    print("Not hot song!")
    
# need to bare in mind that the new song is not the same as inserted by the user
# Out:
# What song shall be checked if it hot right now?kill bill
# Your song is hot, here is another one! Drake & 21 Savage: Spin Bout U

# %%
# get user input
user_input = input("What song shall be checked if it hot right now?").lower()

# check if song is in the list
for i in df.song:
    if user_input in df.song.str.lower():
        random_number = np.random.randint(len(df))
        pick_random = df.song[random_number].title()
        print(f'Your song is hot, here is another one! {pick_random}')
    else:
        print("Not hot song!")
    
# need to bare in mind that the new song is not the same as inserted by the user
# Out:
# What song shall be checked if it hot right now?kill bill
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!
# Not hot song!

# %%
df
# Out:
#                                               artist               song  \
# 0                                      Morgan Wallen         Last Night
# 1                                              Drake    Search & Rescue
# 2                                        Miley Cyrus            Flowers
# 3                                                SZA          Kill Bill
# 4               Metro Boomin, The Weeknd & 21 Savage           Creepin'
# ..                                               ...                ...
# 95                                      Old Dominion        Memory Lane
# 96                                      Carly Pearce  What He Didn't Do
# 97                       Carin Leon X Grupo Frontera        Que Vuelvas
# 98  YoungBoy Never Broke Again Featuring Nicki Minaj                WTF
# 99                                     Morgan Wallen         '98 Braves
#
#                                           artist_song
# 0                           morgan wallen: last night
# 1                              drake: search & rescue
# 2                                miley cyrus: flowers
# 3                                      sza: kill bill
# 4      metro boomin, the weeknd & 21 savage: creepin'
# ..                                                ...
# 95                          old dominion: memory lane
# 96                    carly pearce: what he didn't do
# 97           carin leon x grupo frontera: que vuelvas
# 98  youngboy never broke again featuring nicki min...
# 99                          morgan wallen: '98 braves
#
# [100 rows x 3 columns]

# %%
df.song.str.lower()
# Out:
# 0            last night
# 1       search & rescue
# 2               flowers
# 3             kill bill
# 4              creepin'
#             ...
# 95          memory lane
# 96    what he didn't do
# 97          que vuelvas
# 98                  wtf
# 99           '98 braves
# Name: song, Length: 100, dtype: object
