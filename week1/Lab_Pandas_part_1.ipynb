# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
#http://localhost:8888/tree/Documents/GitHub/IH_DA_FT_MAR_2023/Class_Materials/Pandas/Labs/data
cars_df = pd.read_csv("vehicles.csv")
cars_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
cars_df.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
cars_df
# Out:
#                    Make                Model  Year Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                 2.5
# 1            AM General     FJ8c Post Office  1984                 4.2
# 2            AM General  Post Office DJ5 2WD  1985                 2.5
# 3            AM General  Post Office DJ8 2WD  1985                 4.2
# 4      ASC Incorporated                  GNX  1987                 3.8
# ...                 ...                  ...   ...                 ...
# 35947             smart         fortwo coupe  2013                 1.0
# 35948             smart         fortwo coupe  2014                 1.0
# 35949             smart         fortwo coupe  2015                 1.0
# 35950             smart         fortwo coupe  2016                 0.9
# 35951             smart         fortwo coupe  2016                 0.9
#
#       Cylinders     Transmission        Drivetrain  \
# 0           4.0  Automatic 3-spd     2-Wheel Drive
# ...

# %% [markdown]
# First exploration of the dataset:
#
# 1. How many observations does it have?
# 2. Look at all the columns: do you understand what they mean?
# 3. Look at the raw data: do you see anything weird?
# 4. Look at the data types: are they the expected ones for the information the column contains?

# %%
# 1.
len(cars_df.index)
# Out:
# 35952

# %%
# 2. so far so good

# %%
# 3.
# a. Observations for Fuel Barrels/Year and for CO2 Emission Grams/Mile have different decimal numbers
#cars_df.isnull().values.any()

# %%
# 4.
cars_df.dtypes
# Out:
# Make                       object
# Model                      object
# Year                       object
# Engine Displacement        object
# Cylinders                  object
# Transmission               object
# Drivetrain                 object
# Vehicle Class              object
# Fuel Type                  object
# Fuel Barrels/Year          object
# City MPG                   object
# Highway MPG                object
# Combined MPG               object
# CO2 Emission Grams/Mile    object
# Fuel Cost/Year             object
# dtype: object

# %% [markdown]
# ### Cleaning and wrangling data
#
# 1. Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# 2. Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# 3. Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# 4. convert MPG columns to km_per_liter

# %% [markdown]
# Note:
# <br>Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %%
## Your Code here
# find all first
# dutton_only = cars_df[cars_df['Make'].str.contains('Dutton')]

# cars_df.loc[11012, 'Make'] = 'Dutton'
# cars_df.loc[30164, 'Make'] = 'Dutton'
# cars_df.loc[31754, 'Make'] = 'Dutton'

#print(dutton_only) #there are three


# replace all observations that include Dutton with with Dutton

# %%
# 2.
cars_df['CO2 Emission Grams/Mile']=cars_df['CO2 Emission Grams/Mile'].apply(lambda x: (x*1.60934)/1.60934)
cars_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wq/2vxkh_6d4g7dpxkr5q82nxzh0000gn/T/ipykernel_46977/4142270506.py in <module>
#       1 # 2.
# ----> 2 cars_df['CO2 Emission Grams/Mile']=cars_df['CO2 Emission Grams/Mile'].apply(lambda x: (x*1.60934)/1.60934)
#       3 cars_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ...

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
# Your Code here

# %% [markdown]
# <b> (Optional)

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
## your Code here

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here
